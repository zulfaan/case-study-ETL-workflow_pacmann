# %% [markdown]
# # Task
# ---

# %% [markdown]
# - Membuat ETL Pipeline menggunakan Luigi
# - Proposed ETL Pipeline design adalah sebagai berikut
#
# <center>
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/15-01.png" width=70%>
# </center>
#
# - Task yang harus dilakukan adalah:
#     1. Membuat Pipeline Extract dari source:
#         - [API Payment Data](https://shandytepe.github.io/payment.json)
#         - Database Hotel
#
#        Setelah berhasil melakukan Extract, simpan output `.csv` ke dalam folder `live_class_w8/data/raw`
#
#     2. Membuat Pipeline Validation dari Pipeline Extract data. Proses validasi yang dilakukan adalah:
#         - Check Data Shape
#         - Check Data Types
#         - Check Missing Values
#
#     3. Membuat Pipeline Transform dari Pipeline Extract Data. Proses yang dilakukan adalah:
#         - Join Data dari beberapa source, menjadi satu table data yang baru
#             - Source yang digunakan untuk membuat table baru adalah:
#                 - `payment` (API Payment Data)
#                 - `reservation` (DB Hotel)
#                 - `customer` (DB Hotel)
#
#
# <center>
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/15-02.png" width=80%>
# </center>
#
#
# - Cleaning data
#
#     Setelah berhasil melakukan proses Transform, simpan output `.csv` ke dalam folder `live_class_w8/data/transform`
#
#     4. Membuat Pipeline Load dari Pipeline Transform. Memasukkan table yang baru ke dalam Data Warehouse yang sudah dibuat. Untuk membuat Data Warehouse, bisa melihat dokumentasi di https://github.com/shandytepe/live-class-w8-intro-to-data-eng/tree/main/docker-db
#
#     5. Menggabungkan semua Pipeline menjadi satu dengan menggunakan Luigi
#
#     6. Set schedule pada Pipelien yang sudah dibuat dengan menggunakan `cron`. Set schedule pipeline untuk dijalankan tiap 2 menit sekali. Sehingga, syntax `cron` nya adalah sebagai berikut
#
#         ```bash
#         */2 * * * * /path/to/pipeline.sh
#         ```
#
#     7. Melakukan proses `UPSERT` untuk mengecek robustness dari pipeline yang dibuat
# ---

# %% [markdown]
# ## Extract
# ---

# %%
# import library

import pandas as pd
import requests
import luigi
import json
from urllib import request

# %%
payment_url = 'https://shandytepe.github.io/payment.json'
response = requests.get(payment_url)
response
# Out:
# <Response [200]>

# %%
response = request.urlopen(payment_url)
payment_response = json.loads(response.read().decode('utf-8'))
payment_response
# Out:
# {'payment_data': [{'payment_id': 1,
#    'reservation_id': 1,
#    'provider': 'Ovo',
#    'account_number': 38137149,
#    'payment_status': 'Success',
#    'payment_date': '2020-10-20 17:07:04.406780',
#    'expire_date': '2020-10-28 18:10:37.175108'},
#   {'payment_id': 2,
#    'reservation_id': 2,
#    'provider': 'BCA',
#    'account_number': 42103729,
#    'payment_status': 'Success',
#    'payment_date': '2015-02-28 16:44:56.703511',
#    'expire_date': '2015-03-08 05:27:33.443131'},
#   {'payment_id': 3,
#    'reservation_id': 3,
#    'provider': 'Permata',
#    'account_number': 58689635,
#    'payment_status': 'Success',
#    'payment_date': '2022-04-03 13:27:30.811447',
#    'expire_date': '2022-04-06 14:20:57.846492'},
#   {'payment_id': 4,
#    'reservation_id': 4,
#    'provider': 'BNI',
#    'account_number': 107161965,
#    'payment_status': 'Success',
#    'payment_date': '2019-10-04 08:39:56.034805',
#    'expire_date': '2019-10-08 02:01:21.209415'},
#   {'payment_id': 5,
#    'reservation_id': 5,
#    'provider': 'BSI',
#    'account_number': 14334131,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2020-06-14 12:02:55.669148'},
#   {'payment_id': 6,
#    'reservation_id': 6,
#    'provider': 'Ovo',
#    'account_number': 43583173,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2020-03-25 03:35:27.294069'},
#   {'payment_id': 7,
#    'reservation_id': 7,
#    'provider': 'BSI',
#    'account_number': 21381685,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2017-10-12 03:15:31.976142'},
#   {'payment_id': 8,
#    'reservation_id': 8,
#    'provider': 'Permata',
#    'account_number': 119636925,
#    'payment_status': 'Success',
#    'payment_date': '2019-07-06 00:27:04.653808',
#    'expire_date': '2019-07-16 05:38:12.603096'},
#   {'payment_id': 9,
#    'reservation_id': 9,
#    'provider': 'Mandiri',
#    'account_number': 128447299,
#    'payment_status': 'Success',
#    'payment_date': '2020-10-22 21:58:00.410610',
#    'expire_date': '2020-11-07 21:05:56.055206'},
#   {'payment_id': 10,
#    'reservation_id': 10,
#    'provider': 'BCA',
#    'account_number': 21032743,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-03-23 15:28:53.857496'},
#   {'payment_id': 11,
#    'reservation_id': 11,
#    'provider': 'BCA',
#    'account_number': 16173439,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-30 19:38:38.538543',
#    'expire_date': '2016-01-04 23:05:09.802748'},
#   {'payment_id': 12,
#    'reservation_id': 12,
#    'provider': 'Mandiri',
#    'account_number': 104632264,
#    'payment_status': 'Success',
#    'payment_date': '2016-04-20 11:00:30.806322',
#    'expire_date': '2016-04-29 02:21:20.891066'},
#   {'payment_id': 13,
#    'reservation_id': 13,
#    'provider': 'BSI',
#    'account_number': 43534397,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-03-09 03:35:10.487369'},
#   {'payment_id': 14,
#    'reservation_id': 14,
#    'provider': 'BNI',
#    'account_number': 49889648,
#    'payment_status': 'Success',
#    'payment_date': '2015-08-30 02:50:08.222347',
#    'expire_date': '2015-09-06 15:20:00.703303'},
#   {'payment_id': 15,
#    'reservation_id': 15,
#    'provider': 'Ovo',
#    'account_number': 18430413,
#    'payment_status': 'Success',
#    'payment_date': '2015-08-25 14:16:14.426967',
#    'expire_date': '2015-09-11 10:50:49.605705'},
#   {'payment_id': 16,
#    'reservation_id': 16,
#    'provider': 'BSI',
#    'account_number': 50658732,
#    'payment_status': 'Success',
#    'payment_date': '2015-06-20 02:46:39.973862',
#    'expire_date': '2015-07-14 03:01:07.619775'},
#   {'payment_id': 17,
#    'reservation_id': 17,
#    'provider': 'Permata',
#    'account_number': 127295361,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2017-07-04 16:06:26.397032'},
#   {'payment_id': 18,
#    'reservation_id': 18,
#    'provider': 'Ovo',
#    'account_number': 17623865,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2022-02-07 12:28:06.762768'},
#   {'payment_id': 19,
#    'reservation_id': 19,
#    'provider': 'Permata',
#    'account_number': 45720659,
#    'payment_status': 'Success',
#    'payment_date': '2020-08-13 21:31:51.720690',
#    'expire_date': '2020-08-18 00:19:21.200788'},
#   {'payment_id': 20,
#    'reservation_id': 20,
#    'provider': 'BRI',
#    'account_number': 24522616,
#    'payment_status': 'Success',
#    'payment_date': '2019-04-29 02:30:35.993787',
#    'expire_date': '2019-05-04 07:50:25.941863'},
#   {'payment_id': 21,
#    'reservation_id': 21,
#    'provider': 'BCA',
#    'account_number': 40171274,
#    'payment_status': 'Success',
#    'payment_date': '2016-07-05 21:12:14.843462',
#    'expire_date': '2016-07-23 13:34:21.552345'},
#   {'payment_id': 22,
#    'reservation_id': 22,
#    'provider': 'BSI',
#    'account_number': 87325119,
#    'payment_status': 'Success',
#    'payment_date': '2022-09-14 04:05:25.125170',
#    'expire_date': '2022-09-22 05:26:27.455076'},
#   {'payment_id': 23,
#    'reservation_id': 23,
#    'provider': 'Mandiri',
#    'account_number': 80424842,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2015-12-27 08:40:25.543543'},
#   {'payment_id': 24,
#    'reservation_id': 24,
#    'provider': 'Dana',
#    'account_number': 68014753,
#    'payment_status': 'Success',
#    'payment_date': '2018-04-22 10:35:56.072920',
#    'expire_date': '2018-04-23 08:43:05.754180'},
#   {'payment_id': 25,
#    'reservation_id': 25,
#    'provider': 'Ovo',
#    'account_number': 67955907,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2018-01-23 00:35:29.432422'},
#   {'payment_id': 26,
#    'reservation_id': 26,
#    'provider': 'Ovo',
#    'account_number': 118567367,
#    'payment_status': 'Success',
#    'payment_date': '2022-07-15 21:16:23.550955',
#    'expire_date': '2022-07-18 12:52:41.212040'},
#   {'payment_id': 27,
#    'reservation_id': 27,
#    'provider': 'Mandiri',
#    'account_number': 63877474,
#    'payment_status': 'Success',
#    'payment_date': '2023-09-23 08:40:39.730816',
#    'expire_date': '2023-09-24 01:16:48.101635'},
#   {'payment_id': 28,
#    'reservation_id': 28,
#    'provider': 'Mandiri',
#    'account_number': 56900633,
#    'payment_status': 'Success',
#    'payment_date': '2017-02-05 15:32:32.753439',
#    'expire_date': '2017-02-18 06:59:20.424385'},
#   {'payment_id': 29,
#    'reservation_id': 29,
#    'provider': 'Permata',
#    'account_number': 85393525,
#    'payment_status': 'Success',
#    'payment_date': '2023-01-28 12:45:00.348000',
#    'expire_date': '2023-01-31 03:41:40.888129'},
#   {'payment_id': 30,
#    'reservation_id': 30,
#    'provider': 'BNI',
#    'account_number': 77692616,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2022-10-24 00:18:02.325080'},
#   {'payment_id': 31,
#    'reservation_id': 31,
#    'provider': 'BRI',
#    'account_number': 109047964,
#    'payment_status': 'Success',
#    'payment_date': '2017-05-01 20:28:13.755565',
#    'expire_date': '2017-05-09 08:51:12.372034'},
#   {'payment_id': 32,
#    'reservation_id': 32,
#    'provider': 'Mandiri',
#    'account_number': 42562920,
#    'payment_status': 'Success',
#    'payment_date': '2015-04-19 16:25:57.795156',
#    'expire_date': '2015-04-23 08:29:01.599162'},
#   {'payment_id': 33,
#    'reservation_id': 33,
#    'provider': 'BSI',
#    'account_number': 11185396,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2019-07-04 21:42:17.104614'},
#   {'payment_id': 34,
#    'reservation_id': 34,
#    'provider': 'BNI',
#    'account_number': 126055117,
#    'payment_status': 'Success',
#    'payment_date': '2022-06-29 04:45:09.569007',
#    'expire_date': '2022-07-03 02:19:06.766633'},
#   {'payment_id': 35,
#    'reservation_id': 35,
#    'provider': 'BNI',
#    'account_number': 67319268,
#    'payment_status': 'Success',
#    'payment_date': '2021-03-08 00:19:09.674313',
#    'expire_date': '2021-04-02 21:35:18.446344'},
#   {'payment_id': 36,
#    'reservation_id': 36,
#    'provider': 'BCA',
#    'account_number': 68405388,
#    'payment_status': 'Success',
#    'payment_date': '2019-01-05 08:33:46.361318',
#    'expire_date': '2019-01-09 02:25:55.280077'},
#   {'payment_id': 37,
#    'reservation_id': 37,
#    'provider': 'Permata',
#    'account_number': 74409310,
#    'payment_status': 'Success',
#    'payment_date': '2021-02-22 23:33:09.517954',
#    'expire_date': '2021-03-07 10:41:32.072754'},
#   {'payment_id': 38,
#    'reservation_id': 38,
#    'provider': 'BSI',
#    'account_number': 77891129,
#    'payment_status': 'Success',
#    'payment_date': '2023-08-23 00:36:18.891850',
#    'expire_date': '2023-09-01 14:07:51.339327'},
#   {'payment_id': 39,
#    'reservation_id': 39,
#    'provider': 'BNI',
#    'account_number': 85258754,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2023-03-10 01:12:22.026016'},
#   {'payment_id': 40,
#    'reservation_id': 40,
#    'provider': 'Mandiri',
#    'account_number': 82684305,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2023-12-25 09:52:31.666417'},
#   {'payment_id': 41,
#    'reservation_id': 41,
#    'provider': 'Dana',
#    'account_number': 47696118,
#    'payment_status': 'Success',
#    'payment_date': '2020-02-27 10:00:13.749346',
#    'expire_date': '2020-02-28 04:37:35.641615'},
#   {'payment_id': 42,
#    'reservation_id': 42,
#    'provider': 'Permata',
#    'account_number': 20744456,
#    'payment_status': 'Success',
#    'payment_date': '2022-08-12 06:55:05.659188',
#    'expire_date': '2022-08-24 09:26:35.508498'},
#   {'payment_id': 43,
#    'reservation_id': 43,
#    'provider': 'Permata',
#    'account_number': 93997599,
#    'payment_status': 'Success',
#    'payment_date': '2016-03-15 12:39:13.901383',
#    'expire_date': '2016-04-05 14:50:43.437155'},
#   {'payment_id': 44,
#    'reservation_id': 44,
#    'provider': 'Dana',
#    'account_number': 84870612,
#    'payment_status': 'Success',
#    'payment_date': '2020-07-28 08:11:48.573162',
#    'expire_date': '2020-07-30 06:38:43.895765'},
#   {'payment_id': 45,
#    'reservation_id': 45,
#    'provider': 'BRI',
#    'account_number': 41401341,
#    'payment_status': 'Success',
#    'payment_date': '2022-11-16 11:46:45.890529',
#    'expire_date': '2022-11-26 16:05:43.658527'},
#   {'payment_id': 46,
#    'reservation_id': 46,
#    'provider': 'Dana',
#    'account_number': 114271479,
#    'payment_status': 'Success',
#    'payment_date': '2019-08-13 02:30:29.381232',
#    'expire_date': '2019-08-20 00:39:27.665543'},
#   {'payment_id': 47,
#    'reservation_id': 47,
#    'provider': 'Ovo',
#    'account_number': 49379721,
#    'payment_status': 'Success',
#    'payment_date': '2023-11-26 00:37:55.621649',
#    'expire_date': '2023-12-16 06:31:35.617338'},
#   {'payment_id': 48,
#    'reservation_id': 48,
#    'provider': 'BCA',
#    'account_number': 101980100,
#    'payment_status': 'Success',
#    'payment_date': '2020-11-20 18:33:57.224326',
#    'expire_date': '2020-11-25 15:59:37.295445'},
#   {'payment_id': 49,
#    'reservation_id': 49,
#    'provider': 'Dana',
#    'account_number': 76380741,
#    'payment_status': 'Success',
#    'payment_date': '2021-09-30 22:51:39.392363',
#    'expire_date': '2021-10-02 02:48:59.764712'},
#   {'payment_id': 50,
#    'reservation_id': 50,
#    'provider': 'Dana',
#    'account_number': 120095487,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2021-05-03 19:49:22.287891'},
#   {'payment_id': 51,
#    'reservation_id': 51,
#    'provider': 'Permata',
#    'account_number': 37124593,
#    'payment_status': 'Success',
#    'payment_date': '2023-06-10 08:09:57.495218',
#    'expire_date': '2023-07-02 21:50:33.150085'},
#   {'payment_id': 52,
#    'reservation_id': 52,
#    'provider': 'Dana',
#    'account_number': 57906144,
#    'payment_status': 'Success',
#    'payment_date': '2021-11-14 13:20:46.221819',
#    'expire_date': '2021-11-26 11:07:51.214998'},
#   {'payment_id': 53,
#    'reservation_id': 53,
#    'provider': 'BRI',
#    'account_number': 80320784,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2023-05-11 18:08:14.305635'},
#   {'payment_id': 54,
#    'reservation_id': 54,
#    'provider': 'Permata',
#    'account_number': 85084669,
#    'payment_status': 'Success',
#    'payment_date': '2015-05-31 20:07:04.540371',
#    'expire_date': '2015-06-12 11:54:49.849240'},
#   {'payment_id': 55,
#    'reservation_id': 55,
#    'provider': 'BNI',
#    'account_number': 96554777,
#    'payment_status': 'Success',
#    'payment_date': '2018-12-14 17:32:02.951623',
#    'expire_date': '2018-12-19 04:32:43.135352'},
#   {'payment_id': 56,
#    'reservation_id': 56,
#    'provider': 'Dana',
#    'account_number': 26643726,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2019-06-21 16:11:44.478131'},
#   {'payment_id': 57,
#    'reservation_id': 57,
#    'provider': 'BSI',
#    'account_number': 96309210,
#    'payment_status': 'Success',
#    'payment_date': '2020-04-14 12:15:04.336920',
#    'expire_date': '2020-04-18 06:13:07.614273'},
#   {'payment_id': 58,
#    'reservation_id': 58,
#    'provider': 'BCA',
#    'account_number': 23778636,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2022-01-29 23:14:13.514540'},
#   {'payment_id': 59,
#    'reservation_id': 59,
#    'provider': 'Mandiri',
#    'account_number': 108066807,
#    'payment_status': 'Success',
#    'payment_date': '2017-11-11 03:42:20.481068',
#    'expire_date': '2017-11-13 17:15:11.355283'},
#   {'payment_id': 60,
#    'reservation_id': 60,
#    'provider': 'BRI',
#    'account_number': 110497723,
#    'payment_status': 'Success',
#    'payment_date': '2023-04-15 19:37:12.782132',
#    'expire_date': '2023-04-16 04:38:12.455727'},
#   {'payment_id': 61,
#    'reservation_id': 61,
#    'provider': 'BSI',
#    'account_number': 47423080,
#    'payment_status': 'Success',
#    'payment_date': '2019-03-18 21:20:10.362002',
#    'expire_date': '2019-04-03 22:53:23.095561'},
#   {'payment_id': 62,
#    'reservation_id': 62,
#    'provider': 'Ovo',
#    'account_number': 98612293,
#    'payment_status': 'Success',
#    'payment_date': '2016-06-25 07:11:03.340820',
#    'expire_date': '2016-07-01 17:54:37.944352'},
#   {'payment_id': 63,
#    'reservation_id': 63,
#    'provider': 'BNI',
#    'account_number': 70613362,
#    'payment_status': 'Success',
#    'payment_date': '2019-07-28 11:05:08.955412',
#    'expire_date': '2019-08-03 05:39:22.799905'},
#   {'payment_id': 64,
#    'reservation_id': 64,
#    'provider': 'Dana',
#    'account_number': 89704042,
#    'payment_status': 'Success',
#    'payment_date': '2015-11-18 22:08:04.793063',
#    'expire_date': '2015-11-20 06:28:29.081883'},
#   {'payment_id': 65,
#    'reservation_id': 65,
#    'provider': 'Dana',
#    'account_number': 10612190,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2016-03-03 18:51:54.191916'},
#   {'payment_id': 66,
#    'reservation_id': 66,
#    'provider': 'BRI',
#    'account_number': 84134154,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2019-10-14 14:03:46.277758'},
#   {'payment_id': 67,
#    'reservation_id': 67,
#    'provider': 'Permata',
#    'account_number': 105844734,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2022-09-08 18:50:59.286710'},
#   {'payment_id': 68,
#    'reservation_id': 68,
#    'provider': 'Ovo',
#    'account_number': 114214960,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2019-10-31 02:42:12.650666'},
#   {'payment_id': 69,
#    'reservation_id': 69,
#    'provider': 'Mandiri',
#    'account_number': 82425108,
#    'payment_status': 'Success',
#    'payment_date': '2017-06-28 04:34:19.252113',
#    'expire_date': '2017-06-29 17:37:30.305067'},
#   {'payment_id': 70,
#    'reservation_id': 70,
#    'provider': 'Dana',
#    'account_number': 67195893,
#    'payment_status': 'Success',
#    'payment_date': '2016-10-12 00:28:15.222130',
#    'expire_date': '2016-11-02 18:51:32.716009'},
#   {'payment_id': 71,
#    'reservation_id': 71,
#    'provider': 'BSI',
#    'account_number': 44379182,
#    'payment_status': 'Success',
#    'payment_date': '2022-06-29 01:22:52.919556',
#    'expire_date': '2022-07-04 23:09:59.988440'},
#   {'payment_id': 72,
#    'reservation_id': 72,
#    'provider': 'Permata',
#    'account_number': 71608994,
#    'payment_status': 'Success',
#    'payment_date': '2016-02-07 00:26:54.307496',
#    'expire_date': '2016-02-11 15:01:20.193673'},
#   {'payment_id': 73,
#    'reservation_id': 73,
#    'provider': 'BNI',
#    'account_number': 108631148,
#    'payment_status': 'Success',
#    'payment_date': '2021-01-04 10:40:52.597047',
#    'expire_date': '2021-01-04 13:54:49.421497'},
#   {'payment_id': 74,
#    'reservation_id': 74,
#    'provider': 'BCA',
#    'account_number': 25988916,
#    'payment_status': 'Success',
#    'payment_date': '2015-01-06 18:04:12.385422',
#    'expire_date': '2015-01-13 20:28:42.341184'},
#   {'payment_id': 75,
#    'reservation_id': 75,
#    'provider': 'Ovo',
#    'account_number': 83806784,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2019-04-19 20:22:23.677737'},
#   {'payment_id': 76,
#    'reservation_id': 76,
#    'provider': 'BRI',
#    'account_number': 12041497,
#    'payment_status': 'Success',
#    'payment_date': '2020-07-02 16:13:11.932542',
#    'expire_date': '2020-07-17 17:38:17.101165'},
#   {'payment_id': 77,
#    'reservation_id': 77,
#    'provider': 'Permata',
#    'account_number': 107239033,
#    'payment_status': 'Success',
#    'payment_date': '2023-12-06 22:13:51.614654',
#    'expire_date': '2023-12-18 11:04:15.189224'},
#   {'payment_id': 78,
#    'reservation_id': 78,
#    'provider': 'BSI',
#    'account_number': 105022242,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2015-05-27 12:30:12.943937'},
#   {'payment_id': 79,
#    'reservation_id': 79,
#    'provider': 'Dana',
#    'account_number': 32745579,
#    'payment_status': 'Success',
#    'payment_date': '2017-12-08 05:25:19.282480',
#    'expire_date': '2017-12-30 18:38:36.992419'},
#   {'payment_id': 80,
#    'reservation_id': 80,
#    'provider': 'BRI',
#    'account_number': 91643379,
#    'payment_status': 'Success',
#    'payment_date': '2015-04-17 18:52:42.263507',
#    'expire_date': '2015-04-24 16:40:22.687923'},
#   {'payment_id': 81,
#    'reservation_id': 81,
#    'provider': 'BSI',
#    'account_number': 60394675,
#    'payment_status': 'Success',
#    'payment_date': '2019-06-19 07:26:25.436623',
#    'expire_date': '2019-06-20 09:32:49.233925'},
#   {'payment_id': 82,
#    'reservation_id': 82,
#    'provider': 'Ovo',
#    'account_number': 68940584,
#    'payment_status': 'Success',
#    'payment_date': '2015-08-03 14:06:09.588340',
#    'expire_date': '2015-08-04 23:55:12.720663'},
#   {'payment_id': 83,
#    'reservation_id': 83,
#    'provider': 'Mandiri',
#    'account_number': 68817620,
#    'payment_status': 'Success',
#    'payment_date': '2020-02-21 00:55:12.000211',
#    'expire_date': '2020-03-10 21:05:40.467892'},
#   {'payment_id': 84,
#    'reservation_id': 84,
#    'provider': 'BSI',
#    'account_number': 87382068,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-10-21 17:02:15.577571'},
#   {'payment_id': 85,
#    'reservation_id': 85,
#    'provider': 'BSI',
#    'account_number': 71827432,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2017-09-21 08:23:18.169208'},
#   {'payment_id': 86,
#    'reservation_id': 86,
#    'provider': 'Permata',
#    'account_number': 119271005,
#    'payment_status': 'Success',
#    'payment_date': '2022-06-26 10:53:36.921245',
#    'expire_date': '2022-06-27 17:39:58.972960'},
#   {'payment_id': 87,
#    'reservation_id': 87,
#    'provider': 'BRI',
#    'account_number': 65601897,
#    'payment_status': 'Success',
#    'payment_date': '2016-05-09 04:43:16.673477',
#    'expire_date': '2016-05-23 07:56:07.111872'},
#   {'payment_id': 88,
#    'reservation_id': 88,
#    'provider': 'BCA',
#    'account_number': 36074877,
#    'payment_status': 'Success',
#    'payment_date': '2023-11-10 07:06:09.877160',
#    'expire_date': '2023-11-10 18:03:50.074177'},
#   {'payment_id': 89,
#    'reservation_id': 89,
#    'provider': 'Permata',
#    'account_number': 20016087,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2017-06-18 21:27:53.264377'},
#   {'payment_id': 90,
#    'reservation_id': 90,
#    'provider': 'Mandiri',
#    'account_number': 114214151,
#    'payment_status': 'Success',
#    'payment_date': '2016-12-07 08:09:32.799865',
#    'expire_date': '2016-12-15 01:03:47.632264'},
#   {'payment_id': 91,
#    'reservation_id': 91,
#    'provider': 'BNI',
#    'account_number': 118900458,
#    'payment_status': 'Success',
#    'payment_date': '2020-05-12 05:16:15.834908',
#    'expire_date': '2020-05-18 06:31:50.530652'},
#   {'payment_id': 92,
#    'reservation_id': 92,
#    'provider': 'Dana',
#    'account_number': 97779292,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2020-05-14 09:29:03.113355'},
#   {'payment_id': 93,
#    'reservation_id': 93,
#    'provider': 'Dana',
#    'account_number': 87146592,
#    'payment_status': 'Success',
#    'payment_date': '2021-09-15 06:34:49.551255',
#    'expire_date': '2021-09-19 15:53:29.023623'},
#   {'payment_id': 94,
#    'reservation_id': 94,
#    'provider': 'Dana',
#    'account_number': 96030822,
#    'payment_status': 'Success',
#    'payment_date': '2017-08-09 20:23:13.769201',
#    'expire_date': '2017-09-05 02:41:10.294499'},
#   {'payment_id': 95,
#    'reservation_id': 95,
#    'provider': 'Ovo',
#    'account_number': 40338389,
#    'payment_status': 'Success',
#    'payment_date': '2017-10-17 20:06:21.595450',
#    'expire_date': '2017-11-02 20:23:54.866262'},
#   {'payment_id': 96,
#    'reservation_id': 96,
#    'provider': 'Dana',
#    'account_number': 64513164,
#    'payment_status': 'Success',
#    'payment_date': '2016-01-08 04:26:10.318807',
#    'expire_date': '2016-01-18 15:53:37.992629'},
#   {'payment_id': 97,
#    'reservation_id': 97,
#    'provider': 'Ovo',
#    'account_number': 114181064,
#    'payment_status': 'Success',
#    'payment_date': '2017-11-22 01:42:36.010233',
#    'expire_date': '2017-12-03 05:35:37.078877'},
#   {'payment_id': 98,
#    'reservation_id': 98,
#    'provider': 'BCA',
#    'account_number': 28492784,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2017-12-09 12:07:29.771848'},
#   {'payment_id': 99,
#    'reservation_id': 99,
#    'provider': 'BNI',
#    'account_number': 28958448,
#    'payment_status': 'Success',
#    'payment_date': '2017-09-16 05:54:25.615111',
#    'expire_date': '2017-10-08 18:03:37.462282'},
#   {'payment_id': 100,
#    'reservation_id': 100,
#    'provider': 'BRI',
#    'account_number': 110740894,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-01-05 01:47:16.102226'},
#   {'payment_id': 101,
#    'reservation_id': 101,
#    'provider': 'Ovo',
#    'account_number': 80919755,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-11-17 19:24:15.874585'},
#   {'payment_id': 102,
#    'reservation_id': 102,
#    'provider': 'BRI',
#    'account_number': 78226735,
#    'payment_status': 'Success',
#    'payment_date': '2018-11-02 08:47:58.713702',
#    'expire_date': '2018-11-16 18:14:40.984145'},
#   {'payment_id': 103,
#    'reservation_id': 103,
#    'provider': 'BSI',
#    'account_number': 23332030,
#    'payment_status': 'Success',
#    'payment_date': '2018-02-14 19:33:07.335973',
#    'expire_date': '2018-02-18 06:13:45.235218'},
#   {'payment_id': 104,
#    'reservation_id': 104,
#    'provider': 'Permata',
#    'account_number': 110732310,
#    'payment_status': 'Success',
#    'payment_date': '2018-01-22 00:29:12.397426',
#    'expire_date': '2018-02-04 22:31:48.537877'},
#   {'payment_id': 105,
#    'reservation_id': 105,
#    'provider': 'BRI',
#    'account_number': 13715311,
#    'payment_status': 'Success',
#    'payment_date': '2016-07-02 18:03:58.500839',
#    'expire_date': '2016-07-04 19:05:01.717327'},
#   {'payment_id': 106,
#    'reservation_id': 106,
#    'provider': 'Mandiri',
#    'account_number': 21875816,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2017-03-16 08:25:49.194882'},
#   {'payment_id': 107,
#    'reservation_id': 107,
#    'provider': 'BRI',
#    'account_number': 74041480,
#    'payment_status': 'Success',
#    'payment_date': '2015-07-02 14:04:26.966531',
#    'expire_date': '2015-07-03 01:12:22.413727'},
#   {'payment_id': 108,
#    'reservation_id': 108,
#    'provider': 'BNI',
#    'account_number': 113371710,
#    'payment_status': 'Success',
#    'payment_date': '2016-11-28 18:45:34.751681',
#    'expire_date': '2016-12-04 21:40:25.070383'},
#   {'payment_id': 109,
#    'reservation_id': 109,
#    'provider': 'Dana',
#    'account_number': 13405278,
#    'payment_status': 'Success',
#    'payment_date': '2023-08-07 21:04:13.921606',
#    'expire_date': '2023-08-10 09:33:37.996097'},
#   {'payment_id': 110,
#    'reservation_id': 110,
#    'provider': 'Ovo',
#    'account_number': 16329474,
#    'payment_status': 'Success',
#    'payment_date': '2019-12-23 20:53:00.975248',
#    'expire_date': '2019-12-30 08:55:46.425715'},
#   {'payment_id': 111,
#    'reservation_id': 111,
#    'provider': 'BNI',
#    'account_number': 49043659,
#    'payment_status': 'Success',
#    'payment_date': '2016-09-06 23:26:02.418191',
#    'expire_date': '2016-09-11 22:56:03.510935'},
#   {'payment_id': 112,
#    'reservation_id': 112,
#    'provider': 'Permata',
#    'account_number': 49930076,
#    'payment_status': 'Success',
#    'payment_date': '2023-09-03 03:28:41.011147',
#    'expire_date': '2023-09-19 02:26:55.706436'},
#   {'payment_id': 113,
#    'reservation_id': 113,
#    'provider': 'BSI',
#    'account_number': 108194070,
#    'payment_status': 'Success',
#    'payment_date': '2018-02-01 11:30:54.222723',
#    'expire_date': '2018-02-01 21:17:14.499783'},
#   {'payment_id': 114,
#    'reservation_id': 114,
#    'provider': 'BCA',
#    'account_number': 106385357,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2018-03-13 03:18:42.432090'},
#   {'payment_id': 115,
#    'reservation_id': 115,
#    'provider': 'BRI',
#    'account_number': 112636786,
#    'payment_status': 'Success',
#    'payment_date': '2020-10-04 14:31:20.776764',
#    'expire_date': '2020-10-28 11:20:04.777203'},
#   {'payment_id': 116,
#    'reservation_id': 116,
#    'provider': 'BRI',
#    'account_number': 129528049,
#    'payment_status': 'Success',
#    'payment_date': '2023-07-23 09:23:23.727605',
#    'expire_date': '2023-07-24 22:15:30.736324'},
#   {'payment_id': 117,
#    'reservation_id': 117,
#    'provider': 'BCA',
#    'account_number': 22906027,
#    'payment_status': 'Success',
#    'payment_date': '2017-04-24 20:02:22.709654',
#    'expire_date': '2017-05-05 03:26:28.122766'},
#   {'payment_id': 118,
#    'reservation_id': 118,
#    'provider': 'Permata',
#    'account_number': 117408100,
#    'payment_status': 'Success',
#    'payment_date': '2023-05-22 10:47:22.187549',
#    'expire_date': '2023-05-23 22:47:14.262128'},
#   {'payment_id': 119,
#    'reservation_id': 119,
#    'provider': 'BRI',
#    'account_number': 112265555,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-14 21:41:03.111260',
#    'expire_date': '2016-01-04 10:09:19.323036'},
#   {'payment_id': 120,
#    'reservation_id': 120,
#    'provider': 'Mandiri',
#    'account_number': 54356852,
#    'payment_status': 'Success',
#    'payment_date': '2019-06-01 12:50:33.657788',
#    'expire_date': '2019-06-01 15:36:56.753241'},
#   {'payment_id': 121,
#    'reservation_id': 121,
#    'provider': 'Mandiri',
#    'account_number': 41807369,
#    'payment_status': 'Success',
#    'payment_date': '2020-10-21 05:05:27.481884',
#    'expire_date': '2020-10-23 17:47:19.798209'},
#   {'payment_id': 122,
#    'reservation_id': 122,
#    'provider': 'Mandiri',
#    'account_number': 97538352,
#    'payment_status': 'Success',
#    'payment_date': '2016-02-27 03:00:38.510181',
#    'expire_date': '2016-03-05 23:45:39.355489'},
#   {'payment_id': 123,
#    'reservation_id': 123,
#    'provider': 'BCA',
#    'account_number': 66530718,
#    'payment_status': 'Success',
#    'payment_date': '2015-07-06 02:06:00.974684',
#    'expire_date': '2015-07-06 03:03:56.884537'},
#   {'payment_id': 124,
#    'reservation_id': 124,
#    'provider': 'BNI',
#    'account_number': 59932996,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2021-12-14 06:01:32.181323'},
#   {'payment_id': 125,
#    'reservation_id': 125,
#    'provider': 'BSI',
#    'account_number': 18840304,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2020-12-29 16:39:37.056869'},
#   {'payment_id': 126,
#    'reservation_id': 126,
#    'provider': 'Mandiri',
#    'account_number': 11398248,
#    'payment_status': 'Success',
#    'payment_date': '2019-01-07 20:07:31.978088',
#    'expire_date': '2019-01-10 16:13:01.823892'},
#   {'payment_id': 127,
#    'reservation_id': 127,
#    'provider': 'BNI',
#    'account_number': 109460981,
#    'payment_status': 'Success',
#    'payment_date': '2022-06-27 21:28:30.793051',
#    'expire_date': '2022-06-28 07:13:21.358316'},
#   {'payment_id': 128,
#    'reservation_id': 128,
#    'provider': 'BCA',
#    'account_number': 41809215,
#    'payment_status': 'Success',
#    'payment_date': '2021-06-19 03:11:07.682870',
#    'expire_date': '2021-06-21 20:28:16.700535'},
#   {'payment_id': 129,
#    'reservation_id': 129,
#    'provider': 'BRI',
#    'account_number': 96588484,
#    'payment_status': 'Success',
#    'payment_date': '2019-11-19 15:57:14.924264',
#    'expire_date': '2019-11-22 04:12:02.314389'},
#   {'payment_id': 130,
#    'reservation_id': 130,
#    'provider': 'BNI',
#    'account_number': 82042552,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2015-09-30 13:59:15.409971'},
#   {'payment_id': 131,
#    'reservation_id': 131,
#    'provider': 'BRI',
#    'account_number': 72388763,
#    'payment_status': 'Success',
#    'payment_date': '2021-12-03 07:44:11.045988',
#    'expire_date': '2021-12-04 07:24:19.517922'},
#   {'payment_id': 132,
#    'reservation_id': 132,
#    'provider': 'Dana',
#    'account_number': 15609409,
#    'payment_status': 'Success',
#    'payment_date': '2016-08-09 18:32:53.807626',
#    'expire_date': '2016-08-09 20:04:05.426862'},
#   {'payment_id': 133,
#    'reservation_id': 133,
#    'provider': 'Ovo',
#    'account_number': 39017611,
#    'payment_status': 'Success',
#    'payment_date': '2019-02-16 16:28:10.458898',
#    'expire_date': '2019-02-18 08:43:03.965307'},
#   {'payment_id': 134,
#    'reservation_id': 134,
#    'provider': 'Permata',
#    'account_number': 117282627,
#    'payment_status': 'Success',
#    'payment_date': '2023-12-27 10:44:03.834656',
#    'expire_date': '2024-01-16 01:01:08.301395'},
#   {'payment_id': 135,
#    'reservation_id': 135,
#    'provider': 'BCA',
#    'account_number': 47044524,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2019-01-25 03:46:40.861427'},
#   {'payment_id': 136,
#    'reservation_id': 136,
#    'provider': 'BNI',
#    'account_number': 29371273,
#    'payment_status': 'Success',
#    'payment_date': '2019-01-17 16:20:27.255987',
#    'expire_date': '2019-01-21 12:01:07.673036'},
#   {'payment_id': 137,
#    'reservation_id': 137,
#    'provider': 'BNI',
#    'account_number': 111213346,
#    'payment_status': 'Success',
#    'payment_date': '2017-08-23 13:03:48.717315',
#    'expire_date': '2017-08-23 22:12:07.577083'},
#   {'payment_id': 138,
#    'reservation_id': 138,
#    'provider': 'Mandiri',
#    'account_number': 16702868,
#    'payment_status': 'Success',
#    'payment_date': '2016-01-19 20:59:48.846173',
#    'expire_date': '2016-02-03 11:05:40.177642'},
#   {'payment_id': 139,
#    'reservation_id': 139,
#    'provider': 'Ovo',
#    'account_number': 16640674,
#    'payment_status': 'Success',
#    'payment_date': '2016-09-15 14:06:21.733799',
#    'expire_date': '2016-09-20 18:18:02.814967'},
#   {'payment_id': 140,
#    'reservation_id': 140,
#    'provider': 'Permata',
#    'account_number': 59412021,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2022-11-17 16:59:36.532151'},
#   {'payment_id': 141,
#    'reservation_id': 141,
#    'provider': 'Ovo',
#    'account_number': 100541223,
#    'payment_status': 'Success',
#    'payment_date': '2023-04-15 00:03:55.370521',
#    'expire_date': '2023-04-23 22:20:21.380497'},
#   {'payment_id': 142,
#    'reservation_id': 142,
#    'provider': 'BCA',
#    'account_number': 86038643,
#    'payment_status': 'Success',
#    'payment_date': '2019-04-28 02:43:52.750954',
#    'expire_date': '2019-05-01 09:17:16.101164'},
#   {'payment_id': 143,
#    'reservation_id': 143,
#    'provider': 'BCA',
#    'account_number': 48048794,
#    'payment_status': 'Success',
#    'payment_date': '2020-02-12 04:01:19.147107',
#    'expire_date': '2020-02-18 04:48:48.000036'},
#   {'payment_id': 144,
#    'reservation_id': 144,
#    'provider': 'Dana',
#    'account_number': 111270237,
#    'payment_status': 'Success',
#    'payment_date': '2023-06-16 09:27:51.715434',
#    'expire_date': '2023-06-20 13:00:25.590984'},
#   {'payment_id': 145,
#    'reservation_id': 145,
#    'provider': 'BRI',
#    'account_number': 79459255,
#    'payment_status': 'Success',
#    'payment_date': '2021-02-18 03:52:24.319035',
#    'expire_date': '2021-02-18 04:20:31.544775'},
#   {'payment_id': 146,
#    'reservation_id': 146,
#    'provider': 'BRI',
#    'account_number': 54845703,
#    'payment_status': 'Success',
#    'payment_date': '2017-04-10 19:59:18.441268',
#    'expire_date': '2017-04-16 11:33:13.071346'},
#   {'payment_id': 147,
#    'reservation_id': 147,
#    'provider': 'Ovo',
#    'account_number': 42693530,
#    'payment_status': 'Success',
#    'payment_date': '2021-04-23 16:18:27.078322',
#    'expire_date': '2021-05-11 13:05:54.158927'},
#   {'payment_id': 148,
#    'reservation_id': 148,
#    'provider': 'Mandiri',
#    'account_number': 44557933,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2016-02-14 13:49:58.485357'},
#   {'payment_id': 149,
#    'reservation_id': 149,
#    'provider': 'BRI',
#    'account_number': 79186421,
#    'payment_status': 'Success',
#    'payment_date': '2023-07-02 19:06:42.710580',
#    'expire_date': '2023-07-08 15:59:43.652865'},
#   {'payment_id': 150,
#    'reservation_id': 150,
#    'provider': 'BSI',
#    'account_number': 42117731,
#    'payment_status': 'Success',
#    'payment_date': '2018-05-06 16:53:47.963211',
#    'expire_date': '2018-05-25 05:22:03.362457'},
#   {'payment_id': 151,
#    'reservation_id': 151,
#    'provider': 'Mandiri',
#    'account_number': 80242956,
#    'payment_status': 'Success',
#    'payment_date': '2023-11-09 03:16:16.765855',
#    'expire_date': '2023-11-15 02:23:12.644082'},
#   {'payment_id': 152,
#    'reservation_id': 152,
#    'provider': 'Mandiri',
#    'account_number': 76835487,
#    'payment_status': 'Success',
#    'payment_date': '2023-06-22 09:39:10.432771',
#    'expire_date': '2023-07-01 14:29:01.573892'},
#   {'payment_id': 153,
#    'reservation_id': 153,
#    'provider': 'Ovo',
#    'account_number': 102583247,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-12-03 04:39:34.368109'},
#   {'payment_id': 154,
#    'reservation_id': 154,
#    'provider': 'BNI',
#    'account_number': 91949646,
#    'payment_status': 'Success',
#    'payment_date': '2016-04-25 14:38:10.901873',
#    'expire_date': '2016-05-01 00:16:38.640637'},
#   {'payment_id': 155,
#    'reservation_id': 155,
#    'provider': 'BSI',
#    'account_number': 25537972,
#    'payment_status': 'Success',
#    'payment_date': '2020-05-13 00:04:55.988451',
#    'expire_date': '2020-05-15 15:09:54.575482'},
#   {'payment_id': 156,
#    'reservation_id': 156,
#    'provider': 'BRI',
#    'account_number': 39169459,
#    'payment_status': 'Success',
#    'payment_date': '2023-08-19 21:28:52.649657',
#    'expire_date': '2023-08-31 21:53:59.630568'},
#   {'payment_id': 157,
#    'reservation_id': 157,
#    'provider': 'Permata',
#    'account_number': 87471571,
#    'payment_status': 'Success',
#    'payment_date': '2019-01-19 12:24:41.549844',
#    'expire_date': '2019-02-03 03:15:15.424087'},
#   {'payment_id': 158,
#    'reservation_id': 158,
#    'provider': 'Dana',
#    'account_number': 124194368,
#    'payment_status': 'Success',
#    'payment_date': '2020-07-09 22:46:56.511708',
#    'expire_date': '2020-07-13 21:40:44.117223'},
#   {'payment_id': 159,
#    'reservation_id': 159,
#    'provider': 'BRI',
#    'account_number': 106847031,
#    'payment_status': 'Success',
#    'payment_date': '2018-09-29 23:17:15.479576',
#    'expire_date': '2018-10-11 19:59:25.513807'},
#   {'payment_id': 160,
#    'reservation_id': 160,
#    'provider': 'BNI',
#    'account_number': 54609062,
#    'payment_status': 'Success',
#    'payment_date': '2019-02-20 12:15:47.369503',
#    'expire_date': '2019-02-22 16:52:55.972535'},
#   {'payment_id': 161,
#    'reservation_id': 161,
#    'provider': 'BCA',
#    'account_number': 27093401,
#    'payment_status': 'Success',
#    'payment_date': '2018-06-02 12:08:18.753743',
#    'expire_date': '2018-06-02 16:31:51.790951'},
#   {'payment_id': 162,
#    'reservation_id': 162,
#    'provider': 'BRI',
#    'account_number': 66627773,
#    'payment_status': 'Success',
#    'payment_date': '2017-04-12 13:50:29.168003',
#    'expire_date': '2017-05-07 19:18:39.389801'},
#   {'payment_id': 163,
#    'reservation_id': 163,
#    'provider': 'Permata',
#    'account_number': 31791223,
#    'payment_status': 'Success',
#    'payment_date': '2018-06-22 13:27:13.404152',
#    'expire_date': '2018-07-09 17:18:30.420952'},
#   {'payment_id': 164,
#    'reservation_id': 164,
#    'provider': 'BSI',
#    'account_number': 124214471,
#    'payment_status': 'Success',
#    'payment_date': '2018-03-07 00:43:44.620445',
#    'expire_date': '2018-03-10 12:02:59.063171'},
#   {'payment_id': 165,
#    'reservation_id': 165,
#    'provider': 'Ovo',
#    'account_number': 123479000,
#    'payment_status': 'Success',
#    'payment_date': '2020-06-30 03:24:01.348148',
#    'expire_date': '2020-07-11 18:20:39.305399'},
#   {'payment_id': 166,
#    'reservation_id': 166,
#    'provider': 'BNI',
#    'account_number': 54958645,
#    'payment_status': 'Success',
#    'payment_date': '2022-01-21 01:54:04.836545',
#    'expire_date': '2022-01-23 11:53:46.645468'},
#   {'payment_id': 167,
#    'reservation_id': 167,
#    'provider': 'BNI',
#    'account_number': 63587078,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-22 05:55:21.989877',
#    'expire_date': '2015-12-29 15:27:54.764039'},
#   {'payment_id': 168,
#    'reservation_id': 168,
#    'provider': 'Permata',
#    'account_number': 77313351,
#    'payment_status': 'Success',
#    'payment_date': '2021-07-03 19:29:06.646382',
#    'expire_date': '2021-07-07 01:21:52.214603'},
#   {'payment_id': 169,
#    'reservation_id': 169,
#    'provider': 'BSI',
#    'account_number': 101249401,
#    'payment_status': 'Success',
#    'payment_date': '2016-02-11 16:02:36.491204',
#    'expire_date': '2016-02-14 15:31:48.214677'},
#   {'payment_id': 170,
#    'reservation_id': 170,
#    'provider': 'Permata',
#    'account_number': 109877147,
#    'payment_status': 'Success',
#    'payment_date': '2019-12-10 12:37:15.370073',
#    'expire_date': '2019-12-11 09:30:54.498925'},
#   {'payment_id': 171,
#    'reservation_id': 171,
#    'provider': 'BCA',
#    'account_number': 80373032,
#    'payment_status': 'Success',
#    'payment_date': '2015-03-26 12:38:54.726878',
#    'expire_date': '2015-04-08 09:30:50.754878'},
#   {'payment_id': 172,
#    'reservation_id': 172,
#    'provider': 'Permata',
#    'account_number': 69235939,
#    'payment_status': 'Success',
#    'payment_date': '2018-09-28 06:14:54.129614',
#    'expire_date': '2018-10-18 04:59:54.349504'},
#   {'payment_id': 173,
#    'reservation_id': 173,
#    'provider': 'BRI',
#    'account_number': 18507401,
#    'payment_status': 'Success',
#    'payment_date': '2019-06-02 07:04:43.993247',
#    'expire_date': '2019-06-03 19:54:23.800926'},
#   {'payment_id': 174,
#    'reservation_id': 174,
#    'provider': 'BSI',
#    'account_number': 34401248,
#    'payment_status': 'Success',
#    'payment_date': '2017-09-21 16:33:37.887047',
#    'expire_date': '2017-10-18 17:51:43.088299'},
#   {'payment_id': 175,
#    'reservation_id': 175,
#    'provider': 'BCA',
#    'account_number': 41300824,
#    'payment_status': 'Success',
#    'payment_date': '2015-11-13 06:37:48.464276',
#    'expire_date': '2015-11-17 06:47:37.032094'},
#   {'payment_id': 176,
#    'reservation_id': 176,
#    'provider': 'BCA',
#    'account_number': 58549979,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2023-06-29 22:01:22.599403'},
#   {'payment_id': 177,
#    'reservation_id': 177,
#    'provider': 'BCA',
#    'account_number': 63199262,
#    'payment_status': 'Success',
#    'payment_date': '2023-10-28 03:18:58.367911',
#    'expire_date': '2023-10-29 09:51:10.654858'},
#   {'payment_id': 178,
#    'reservation_id': 178,
#    'provider': 'Ovo',
#    'account_number': 10014277,
#    'payment_status': 'Success',
#    'payment_date': '2022-11-25 20:14:55.940342',
#    'expire_date': '2022-11-30 14:20:27.780655'},
#   {'payment_id': 179,
#    'reservation_id': 179,
#    'provider': 'Permata',
#    'account_number': 65642898,
#    'payment_status': 'Success',
#    'payment_date': '2021-06-05 13:57:59.558218',
#    'expire_date': '2021-06-10 01:52:37.988964'},
#   {'payment_id': 180,
#    'reservation_id': 180,
#    'provider': 'BNI',
#    'account_number': 126038312,
#    'payment_status': 'Success',
#    'payment_date': '2018-05-25 02:37:08.440257',
#    'expire_date': '2018-06-05 11:57:28.949289'},
#   {'payment_id': 181,
#    'reservation_id': 181,
#    'provider': 'Mandiri',
#    'account_number': 26549435,
#    'payment_status': 'Success',
#    'payment_date': '2022-10-28 15:30:17.644577',
#    'expire_date': '2022-11-20 03:35:53.738789'},
#   {'payment_id': 182,
#    'reservation_id': 182,
#    'provider': 'BNI',
#    'account_number': 88516516,
#    'payment_status': 'Success',
#    'payment_date': '2022-12-11 00:43:33.338789',
#    'expire_date': '2022-12-20 02:54:14.937999'},
#   {'payment_id': 183,
#    'reservation_id': 183,
#    'provider': 'BNI',
#    'account_number': 34710201,
#    'payment_status': 'Success',
#    'payment_date': '2016-01-09 19:17:47.198600',
#    'expire_date': '2016-01-27 16:18:40.414838'},
#   {'payment_id': 184,
#    'reservation_id': 184,
#    'provider': 'Mandiri',
#    'account_number': 57878450,
#    'payment_status': 'Success',
#    'payment_date': '2020-09-06 18:23:43.109530',
#    'expire_date': '2020-09-20 10:14:00.984320'},
#   {'payment_id': 185,
#    'reservation_id': 185,
#    'provider': 'BCA',
#    'account_number': 78598146,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2017-08-16 04:47:21.264243'},
#   {'payment_id': 186,
#    'reservation_id': 186,
#    'provider': 'BCA',
#    'account_number': 46651442,
#    'payment_status': 'Success',
#    'payment_date': '2016-10-27 11:30:25.573634',
#    'expire_date': '2016-11-02 17:05:44.200757'},
#   {'payment_id': 187,
#    'reservation_id': 187,
#    'provider': 'BCA',
#    'account_number': 107701626,
#    'payment_status': 'Success',
#    'payment_date': '2022-04-28 07:56:35.947174',
#    'expire_date': '2022-04-28 08:10:31.081400'},
#   {'payment_id': 188,
#    'reservation_id': 188,
#    'provider': 'BRI',
#    'account_number': 29682302,
#    'payment_status': 'Success',
#    'payment_date': '2023-11-21 12:34:46.036125',
#    'expire_date': '2023-11-25 15:58:03.148238'},
#   {'payment_id': 189,
#    'reservation_id': 189,
#    'provider': 'BSI',
#    'account_number': 123004857,
#    'payment_status': 'Success',
#    'payment_date': '2020-10-09 00:19:49.261073',
#    'expire_date': '2020-10-24 02:49:59.590446'},
#   {'payment_id': 190,
#    'reservation_id': 190,
#    'provider': 'Dana',
#    'account_number': 114349039,
#    'payment_status': 'Success',
#    'payment_date': '2023-10-03 14:43:32.484229',
#    'expire_date': '2023-10-08 14:35:25.300361'},
#   {'payment_id': 191,
#    'reservation_id': 191,
#    'provider': 'BRI',
#    'account_number': 125746304,
#    'payment_status': 'Success',
#    'payment_date': '2018-12-07 21:55:44.156512',
#    'expire_date': '2018-12-08 22:53:02.171152'},
#   {'payment_id': 192,
#    'reservation_id': 192,
#    'provider': 'Mandiri',
#    'account_number': 63670354,
#    'payment_status': 'Success',
#    'payment_date': '2021-08-26 17:30:40.715873',
#    'expire_date': '2021-08-28 00:34:18.179986'},
#   {'payment_id': 193,
#    'reservation_id': 193,
#    'provider': 'Dana',
#    'account_number': 10302882,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-25 00:50:38.585410',
#    'expire_date': '2016-01-04 12:03:11.355007'},
#   {'payment_id': 194,
#    'reservation_id': 194,
#    'provider': 'BSI',
#    'account_number': 65368334,
#    'payment_status': 'Success',
#    'payment_date': '2023-04-10 21:24:44.500267',
#    'expire_date': '2023-04-15 01:45:09.596613'},
#   {'payment_id': 195,
#    'reservation_id': 195,
#    'provider': 'Permata',
#    'account_number': 39803058,
#    'payment_status': 'Success',
#    'payment_date': '2018-05-21 12:56:53.241315',
#    'expire_date': '2018-05-29 01:28:50.020919'},
#   {'payment_id': 196,
#    'reservation_id': 196,
#    'provider': 'Dana',
#    'account_number': 20122829,
#    'payment_status': 'Success',
#    'payment_date': '2018-09-14 07:16:35.215303',
#    'expire_date': '2018-09-25 22:10:24.376197'},
#   {'payment_id': 197,
#    'reservation_id': 197,
#    'provider': 'BCA',
#    'account_number': 90955301,
#    'payment_status': 'Success',
#    'payment_date': '2015-04-19 14:47:01.301823',
#    'expire_date': '2015-04-20 22:04:46.409067'},
#   {'payment_id': 198,
#    'reservation_id': 198,
#    'provider': 'Ovo',
#    'account_number': 39095633,
#    'payment_status': 'Success',
#    'payment_date': '2018-03-11 06:56:26.821844',
#    'expire_date': '2018-03-16 08:08:53.345046'},
#   {'payment_id': 199,
#    'reservation_id': 199,
#    'provider': 'Mandiri',
#    'account_number': 46651756,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2022-09-23 14:24:59.100139'},
#   {'payment_id': 200,
#    'reservation_id': 200,
#    'provider': 'BSI',
#    'account_number': 82534921,
#    'payment_status': 'Success',
#    'payment_date': '2019-07-16 13:36:57.936175',
#    'expire_date': '2019-07-17 05:49:57.765453'},
#   {'payment_id': 201,
#    'reservation_id': 201,
#    'provider': 'Permata',
#    'account_number': 24894917,
#    'payment_status': 'Success',
#    'payment_date': '2023-09-11 19:54:54.931093',
#    'expire_date': '2023-09-24 04:53:53.233677'},
#   {'payment_id': 202,
#    'reservation_id': 202,
#    'provider': 'Dana',
#    'account_number': 27122262,
#    'payment_status': 'Success',
#    'payment_date': '2017-06-30 15:58:43.385267',
#    'expire_date': '2017-07-16 18:10:36.076783'},
#   {'payment_id': 203,
#    'reservation_id': 203,
#    'provider': 'Ovo',
#    'account_number': 122565481,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2019-01-06 01:49:17.412013'},
#   {'payment_id': 204,
#    'reservation_id': 204,
#    'provider': 'BNI',
#    'account_number': 91961527,
#    'payment_status': 'Success',
#    'payment_date': '2023-04-12 21:11:14.982286',
#    'expire_date': '2023-04-13 00:39:56.231242'},
#   {'payment_id': 205,
#    'reservation_id': 205,
#    'provider': 'BNI',
#    'account_number': 40044204,
#    'payment_status': 'Success',
#    'payment_date': '2015-10-12 01:48:34.172526',
#    'expire_date': '2015-10-13 10:14:28.014286'},
#   {'payment_id': 206,
#    'reservation_id': 206,
#    'provider': 'Dana',
#    'account_number': 12702794,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2016-01-08 08:18:20.591490'},
#   {'payment_id': 207,
#    'reservation_id': 207,
#    'provider': 'BNI',
#    'account_number': 13289119,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2016-10-18 19:44:29.455633'},
#   {'payment_id': 208,
#    'reservation_id': 208,
#    'provider': 'Permata',
#    'account_number': 13697992,
#    'payment_status': 'Success',
#    'payment_date': '2016-05-13 18:40:40.985053',
#    'expire_date': '2016-05-19 08:29:00.567663'},
#   {'payment_id': 209,
#    'reservation_id': 209,
#    'provider': 'BSI',
#    'account_number': 79933247,
#    'payment_status': 'Success',
#    'payment_date': '2016-10-09 03:25:04.053241',
#    'expire_date': '2016-10-11 02:20:31.404556'},
#   {'payment_id': 210,
#    'reservation_id': 210,
#    'provider': 'Mandiri',
#    'account_number': 69488375,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-05-04 11:40:27.803050'},
#   {'payment_id': 211,
#    'reservation_id': 211,
#    'provider': 'BCA',
#    'account_number': 68711373,
#    'payment_status': 'Success',
#    'payment_date': '2016-10-13 08:56:58.526401',
#    'expire_date': '2016-11-03 00:19:27.595635'},
#   {'payment_id': 212,
#    'reservation_id': 212,
#    'provider': 'BSI',
#    'account_number': 118066127,
#    'payment_status': 'Success',
#    'payment_date': '2020-05-14 04:02:06.802668',
#    'expire_date': '2020-05-28 08:52:24.379870'},
#   {'payment_id': 213,
#    'reservation_id': 213,
#    'provider': 'BCA',
# ...
#    'payment_date': '2023-02-11 07:57:46.426723',
#    'expire_date': '2023-02-21 05:24:46.432441'},
#   {'payment_id': 332,
#    'reservation_id': 332,
#    'provider': 'BRI',
#    'account_number': 32064519,
#    'payment_status': 'Success',
#    'payment_date': '2018-05-14 23:26:29.780702',
#    'expire_date': '2018-05-20 19:10:50.746744'},
#   {'payment_id': 333,
#    'reservation_id': 333,
#    'provider': 'Dana',
#    'account_number': 48381118,
#    'payment_status': 'Success',
#    'payment_date': '2017-12-01 16:02:49.947459',
#    'expire_date': '2017-12-13 14:49:35.759579'},
#   {'payment_id': 334,
#    'reservation_id': 334,
#    'provider': 'BRI',
#    'account_number': 78524987,
#    'payment_status': 'Success',
#    'payment_date': '2016-12-01 12:55:25.586344',
#    'expire_date': '2016-12-03 08:11:41.129121'},
#   {'payment_id': 335,
#    'reservation_id': 335,
#    'provider': 'Mandiri',
#    'account_number': 74142017,
#    'payment_status': 'Success',
#    'payment_date': '2019-06-25 03:20:35.476888',
#    'expire_date': '2019-07-05 18:25:11.855975'},
#   {'payment_id': 336,
#    'reservation_id': 336,
#    'provider': 'BSI',
#    'account_number': 37632784,
#    'payment_status': 'Success',
#    'payment_date': '2015-04-21 08:03:51.220644',
#    'expire_date': '2015-04-26 10:10:16.873324'},
#   {'payment_id': 337,
#    'reservation_id': 337,
#    'provider': 'BNI',
#    'account_number': 114018771,
#    'payment_status': 'Success',
#    'payment_date': '2018-08-26 23:17:55.605027',
#    'expire_date': '2018-09-06 15:32:43.503367'},
#   {'payment_id': 338,
#    'reservation_id': 338,
#    'provider': 'Permata',
#    'account_number': 125478300,
#    'payment_status': 'Success',
#    'payment_date': '2018-04-07 15:28:35.192269',
#    'expire_date': '2018-04-10 23:21:23.149234'},
#   {'payment_id': 339,
#    'reservation_id': 339,
#    'provider': 'Permata',
#    'account_number': 17350604,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2023-02-11 19:21:27.303672'},
#   {'payment_id': 340,
#    'reservation_id': 340,
#    'provider': 'BNI',
#    'account_number': 119934834,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2016-07-17 03:50:33.098708'},
#   {'payment_id': 341,
#    'reservation_id': 341,
#    'provider': 'Mandiri',
#    'account_number': 35213037,
#    'payment_status': 'Success',
#    'payment_date': '2021-12-19 01:12:27.407285',
#    'expire_date': '2021-12-21 07:18:17.496687'},
#   {'payment_id': 342,
#    'reservation_id': 342,
#    'provider': 'Mandiri',
#    'account_number': 120792201,
#    'payment_status': 'Success',
#    'payment_date': '2021-03-06 01:49:22.066229',
#    'expire_date': '2021-03-20 04:19:55.538081'},
#   {'payment_id': 343,
#    'reservation_id': 343,
#    'provider': 'Dana',
#    'account_number': 44179544,
#    'payment_status': 'Success',
#    'payment_date': '2022-10-26 11:56:14.214036',
#    'expire_date': '2022-10-28 23:17:05.220141'},
#   {'payment_id': 344,
#    'reservation_id': 344,
#    'provider': 'Mandiri',
#    'account_number': 42208637,
#    'payment_status': 'Success',
#    'payment_date': '2022-08-18 13:55:42.364438',
#    'expire_date': '2022-08-26 23:21:03.369318'},
#   {'payment_id': 345,
#    'reservation_id': 345,
#    'provider': 'Mandiri',
#    'account_number': 13046462,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2015-07-23 23:02:23.078016'},
#   {'payment_id': 346,
#    'reservation_id': 346,
#    'provider': 'BNI',
#    'account_number': 41880344,
#    'payment_status': 'Success',
#    'payment_date': '2019-11-28 21:23:50.921446',
#    'expire_date': '2019-11-30 14:39:17.625525'},
#   {'payment_id': 347,
#    'reservation_id': 347,
#    'provider': 'Permata',
#    'account_number': 87957079,
#    'payment_status': 'Success',
#    'payment_date': '2017-06-20 12:23:30.512528',
#    'expire_date': '2017-06-22 01:55:36.583813'},
#   {'payment_id': 348,
#    'reservation_id': 348,
#    'provider': 'BSI',
#    'account_number': 126295566,
#    'payment_status': 'Success',
#    'payment_date': '2021-01-26 23:15:09.859367',
#    'expire_date': '2021-01-29 19:08:28.873204'},
#   {'payment_id': 349,
#    'reservation_id': 349,
#    'provider': 'Mandiri',
#    'account_number': 82894360,
#    'payment_status': 'Success',
#    'payment_date': '2018-09-06 21:58:06.700745',
#    'expire_date': '2018-09-06 23:21:55.677007'},
#   {'payment_id': 350,
#    'reservation_id': 350,
#    'provider': 'BNI',
#    'account_number': 45455649,
#    'payment_status': 'Success',
#    'payment_date': '2017-06-10 09:07:01.365411',
#    'expire_date': '2017-06-14 00:26:18.932886'},
#   {'payment_id': 351,
#    'reservation_id': 351,
#    'provider': 'Dana',
#    'account_number': 65207958,
#    'payment_status': 'Success',
#    'payment_date': '2023-02-04 00:35:40.930679',
#    'expire_date': '2023-02-04 22:02:48.346734'},
#   {'payment_id': 352,
#    'reservation_id': 352,
#    'provider': 'Mandiri',
#    'account_number': 40036005,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2017-08-29 22:00:17.489099'},
#   {'payment_id': 353,
#    'reservation_id': 353,
#    'provider': 'BCA',
#    'account_number': 124232851,
#    'payment_status': 'Success',
#    'payment_date': '2018-07-21 21:13:47.652093',
#    'expire_date': '2018-07-22 12:47:27.626851'},
#   {'payment_id': 354,
#    'reservation_id': 354,
#    'provider': 'Permata',
#    'account_number': 82466905,
#    'payment_status': 'Success',
#    'payment_date': '2016-05-13 04:38:52.888296',
#    'expire_date': '2016-05-21 11:12:12.024377'},
#   {'payment_id': 355,
#    'reservation_id': 355,
#    'provider': 'BNI',
#    'account_number': 20163053,
#    'payment_status': 'Success',
#    'payment_date': '2020-06-14 02:18:01.141927',
#    'expire_date': '2020-06-15 12:09:07.544627'},
#   {'payment_id': 356,
#    'reservation_id': 356,
#    'provider': 'BSI',
#    'account_number': 39598169,
#    'payment_status': 'Success',
#    'payment_date': '2018-06-15 05:30:56.491822',
#    'expire_date': '2018-06-18 12:38:18.793011'},
#   {'payment_id': 357,
#    'reservation_id': 357,
#    'provider': 'Ovo',
#    'account_number': 35940245,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-26 13:04:05.638380',
#    'expire_date': '2015-12-30 22:50:19.297004'},
#   {'payment_id': 358,
#    'reservation_id': 358,
#    'provider': 'BCA',
#    'account_number': 69723412,
#    'payment_status': 'Success',
#    'payment_date': '2022-10-01 20:08:14.928963',
#    'expire_date': '2022-10-13 00:41:26.293057'},
#   {'payment_id': 359,
#    'reservation_id': 359,
#    'provider': 'BNI',
#    'account_number': 74436273,
#    'payment_status': 'Success',
#    'payment_date': '2023-02-14 17:14:28.157521',
#    'expire_date': '2023-02-23 14:51:11.195061'},
#   {'payment_id': 360,
#    'reservation_id': 360,
#    'provider': 'BCA',
#    'account_number': 121431147,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2017-11-10 01:27:48.900169'},
#   {'payment_id': 361,
#    'reservation_id': 361,
#    'provider': 'BRI',
#    'account_number': 34206427,
#    'payment_status': 'Success',
#    'payment_date': '2017-08-04 07:33:26.174709',
#    'expire_date': '2017-08-06 22:37:31.529830'},
#   {'payment_id': 362,
#    'reservation_id': 362,
#    'provider': 'Permata',
#    'account_number': 20811949,
#    'payment_status': 'Success',
#    'payment_date': '2018-02-09 14:12:08.958242',
#    'expire_date': '2018-02-12 12:42:59.522608'},
#   {'payment_id': 363,
#    'reservation_id': 363,
#    'provider': 'Dana',
#    'account_number': 93189637,
#    'payment_status': 'Success',
#    'payment_date': '2022-11-01 20:25:24.378679',
#    'expire_date': '2022-11-02 09:43:01.178686'},
#   {'payment_id': 364,
#    'reservation_id': 364,
#    'provider': 'Permata',
#    'account_number': 96987506,
#    'payment_status': 'Success',
#    'payment_date': '2015-04-28 21:38:23.612644',
#    'expire_date': '2015-04-29 07:52:00.022109'},
#   {'payment_id': 365,
#    'reservation_id': 365,
#    'provider': 'Dana',
#    'account_number': 37824013,
#    'payment_status': 'Success',
#    'payment_date': '2022-10-26 20:48:51.086795',
#    'expire_date': '2022-11-15 15:58:41.779993'},
#   {'payment_id': 366,
#    'reservation_id': 366,
#    'provider': 'Permata',
#    'account_number': 129938516,
#    'payment_status': 'Success',
#    'payment_date': '2021-09-19 08:24:19.630711',
#    'expire_date': '2021-09-19 20:59:47.731668'},
#   {'payment_id': 367,
#    'reservation_id': 367,
#    'provider': 'Dana',
#    'account_number': 32621538,
#    'payment_status': 'Success',
#    'payment_date': '2023-02-27 21:18:20.276534',
#    'expire_date': '2023-03-05 01:47:35.819903'},
#   {'payment_id': 368,
#    'reservation_id': 368,
#    'provider': 'Mandiri',
#    'account_number': 120036093,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2018-04-26 12:57:12.853697'},
#   {'payment_id': 369,
#    'reservation_id': 369,
#    'provider': 'Ovo',
#    'account_number': 17486743,
#    'payment_status': 'Success',
#    'payment_date': '2021-08-21 04:40:48.302697',
#    'expire_date': '2021-08-25 03:27:43.406678'},
#   {'payment_id': 370,
#    'reservation_id': 370,
#    'provider': 'Permata',
#    'account_number': 109708591,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2020-02-27 13:25:36.002355'},
#   {'payment_id': 371,
#    'reservation_id': 371,
#    'provider': 'Ovo',
#    'account_number': 108954579,
#    'payment_status': 'Success',
#    'payment_date': '2018-02-22 18:14:18.947975',
#    'expire_date': '2018-02-23 14:31:12.097829'},
#   {'payment_id': 372,
#    'reservation_id': 372,
#    'provider': 'Ovo',
#    'account_number': 71579340,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2018-05-28 17:52:10.698413'},
#   {'payment_id': 373,
#    'reservation_id': 373,
#    'provider': 'BSI',
#    'account_number': 70429255,
#    'payment_status': 'Success',
#    'payment_date': '2022-02-13 08:37:23.657387',
#    'expire_date': '2022-02-23 04:39:27.984751'},
#   {'payment_id': 374,
#    'reservation_id': 374,
#    'provider': 'Ovo',
#    'account_number': 98554571,
#    'payment_status': 'Success',
#    'payment_date': '2017-11-06 20:20:43.685437',
#    'expire_date': '2017-11-29 22:41:25.086387'},
#   {'payment_id': 375,
#    'reservation_id': 375,
#    'provider': 'BRI',
#    'account_number': 107033132,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2020-03-05 05:08:17.570280'},
#   {'payment_id': 376,
#    'reservation_id': 376,
#    'provider': 'BSI',
#    'account_number': 41985553,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2015-08-12 03:03:07.843925'},
#   {'payment_id': 377,
#    'reservation_id': 377,
#    'provider': 'BSI',
#    'account_number': 53090779,
#    'payment_status': 'Success',
#    'payment_date': '2018-01-15 01:37:36.460337',
#    'expire_date': '2018-01-15 05:10:29.307026'},
#   {'payment_id': 378,
#    'reservation_id': 378,
#    'provider': 'BRI',
#    'account_number': 111025534,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-12 11:38:08.178944',
#    'expire_date': '2016-01-01 07:44:17.242416'},
#   {'payment_id': 379,
#    'reservation_id': 379,
#    'provider': 'Mandiri',
#    'account_number': 116959090,
#    'payment_status': 'Success',
#    'payment_date': '2022-08-17 02:10:06.371427',
#    'expire_date': '2022-08-21 17:21:48.899772'},
#   {'payment_id': 380,
#    'reservation_id': 380,
#    'provider': 'Dana',
#    'account_number': 86462824,
#    'payment_status': 'Success',
#    'payment_date': '2020-03-07 07:25:04.374195',
#    'expire_date': '2020-03-21 17:39:38.126003'},
#   {'payment_id': 381,
#    'reservation_id': 381,
#    'provider': 'Ovo',
#    'account_number': 45893984,
#    'payment_status': 'Success',
#    'payment_date': '2021-08-16 05:42:28.857338',
#    'expire_date': '2021-08-17 21:38:25.669432'},
#   {'payment_id': 382,
#    'reservation_id': 382,
#    'provider': 'BNI',
#    'account_number': 80662853,
#    'payment_status': 'Success',
#    'payment_date': '2017-08-20 11:59:29.038824',
#    'expire_date': '2017-08-30 18:07:23.957288'},
#   {'payment_id': 383,
#    'reservation_id': 383,
#    'provider': 'BSI',
#    'account_number': 90071544,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2022-01-15 17:13:26.608444'},
#   {'payment_id': 384,
#    'reservation_id': 384,
#    'provider': 'Permata',
#    'account_number': 126704617,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2023-08-03 04:00:49.376104'},
#   {'payment_id': 385,
#    'reservation_id': 385,
#    'provider': 'Ovo',
#    'account_number': 52492899,
#    'payment_status': 'Success',
#    'payment_date': '2016-02-07 08:10:53.678703',
#    'expire_date': '2016-02-11 15:08:17.312110'},
#   {'payment_id': 386,
#    'reservation_id': 386,
#    'provider': 'BNI',
#    'account_number': 103187176,
#    'payment_status': 'Success',
#    'payment_date': '2015-03-31 01:01:56.088207',
#    'expire_date': '2015-04-11 23:26:17.388460'},
#   {'payment_id': 387,
#    'reservation_id': 387,
#    'provider': 'BCA',
#    'account_number': 65830710,
#    'payment_status': 'Success',
#    'payment_date': '2017-11-15 03:09:31.679482',
#    'expire_date': '2017-11-16 05:46:19.977516'},
#   {'payment_id': 388,
#    'reservation_id': 388,
#    'provider': 'Dana',
#    'account_number': 14223006,
#    'payment_status': 'Success',
#    'payment_date': '2018-06-11 03:46:04.923882',
#    'expire_date': '2018-06-14 22:27:41.324386'},
#   {'payment_id': 389,
#    'reservation_id': 389,
#    'provider': 'Ovo',
#    'account_number': 65955077,
#    'payment_status': 'Waiting',
#    'payment_date': None,
#    'expire_date': '2020-05-07 08:32:38.700545'},
#   {'payment_id': 390,
#    'reservation_id': 390,
#    'provider': 'BRI',
#    'account_number': 54895410,
#    'payment_status': 'Success',
#    'payment_date': '2021-01-28 17:55:04.158682',
#    'expire_date': '2021-02-11 03:59:44.180000'},
#   {'payment_id': 391,
#    'reservation_id': 391,
#    'provider': 'BCA',
#    'account_number': 74879911,
#    'payment_status': 'Success',
#    'payment_date': '2023-04-04 20:22:56.788619',
#    'expire_date': '2023-04-06 04:45:28.230730'},
#   {'payment_id': 392,
#    'reservation_id': 392,
#    'provider': 'BRI',
#    'account_number': 62639309,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2017-10-03 00:43:08.511454'},
#   {'payment_id': 393,
#    'reservation_id': 393,
#    'provider': 'BCA',
#    'account_number': 98952869,
#    'payment_status': 'Success',
#    'payment_date': '2016-11-22 20:59:14.248305',
#    'expire_date': '2016-11-24 00:23:56.900516'},
#   {'payment_id': 394,
#    'reservation_id': 394,
#    'provider': 'Ovo',
#    'account_number': 30478987,
#    'payment_status': 'Success',
#    'payment_date': '2016-08-25 09:28:02.575963',
#    'expire_date': '2016-09-02 14:04:00.621696'},
#   {'payment_id': 395,
#    'reservation_id': 395,
#    'provider': 'BSI',
#    'account_number': 31970536,
#    'payment_status': 'Success',
#    'payment_date': '2018-11-30 17:38:44.023934',
#    'expire_date': '2018-11-30 22:50:16.828766'},
#   {'payment_id': 396,
#    'reservation_id': 396,
#    'provider': 'BCA',
#    'account_number': 74033029,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2021-03-18 08:22:51.726001'},
#   {'payment_id': 397,
#    'reservation_id': 397,
#    'provider': 'Permata',
#    'account_number': 87836019,
#    'payment_status': 'Success',
#    'payment_date': '2018-08-05 09:22:05.983116',
#    'expire_date': '2018-08-27 12:44:56.532991'},
#   {'payment_id': 398,
#    'reservation_id': 398,
#    'provider': 'Mandiri',
#    'account_number': 50997930,
#    'payment_status': 'Failed',
#    'payment_date': None,
#    'expire_date': '2022-04-19 12:35:51.127022'},
#   {'payment_id': 399,
#    'reservation_id': 399,
#    'provider': 'Ovo',
#    'account_number': 44305033,
#    'payment_status': 'Success',
#    'payment_date': '2015-12-12 22:35:15.569310',
#    'expire_date': '2015-12-19 19:28:08.809478'},
#   {'payment_id': 400,
#    'reservation_id': 400,
#    'provider': 'BNI',
#    'account_number': 84875963,
#    'payment_status': 'Success',
#    'payment_date': '2021-07-29 16:38:06.052542',
#    'expire_date': '2021-08-02 22:27:28.713637'},
#   {'payment_id': 401,
#    'reservation_id': 401,
#    'provider': 'BCA',
#    'account_number': 11111111,
#    'payment_status': 'Success',
#    'payment_date': '2024-02-14 00:30:15.052542',
#    'expire_date': '2024-02-15 00:30:15.052542'}]}

# %%
response = requests.get(payment_url)
payment_json = response.json()
payment_data = payment_json['payment_data']
payment_df = pd.DataFrame(payment_data)

payment_df
# Out:
#      payment_id  reservation_id provider  account_number payment_status  \
# 0             1               1      Ovo        38137149        Success
# 1             2               2      BCA        42103729        Success
# 2             3               3  Permata        58689635        Success
# 3             4               4      BNI       107161965        Success
# 4             5               5      BSI        14334131         Failed
# ..          ...             ...      ...             ...            ...
# 396         397             397  Permata        87836019        Success
# 397         398             398  Mandiri        50997930         Failed
# 398         399             399      Ovo        44305033        Success
# 399         400             400      BNI        84875963        Success
# 400         401             401      BCA        11111111        Success
#
#                    payment_date                 expire_date
# 0    2020-10-20 17:07:04.406780  2020-10-28 18:10:37.175108
# 1    2015-02-28 16:44:56.703511  2015-03-08 05:27:33.443131
# 2    2022-04-03 13:27:30.811447  2022-04-06 14:20:57.846492
# 3    2019-10-04 08:39:56.034805  2019-10-08 02:01:21.209415
# 4                          None  2020-06-14 12:02:55.669148
# ..                          ...                         ...
# 396  2018-08-05 09:22:05.983116  2018-08-27 12:44:56.532991
# 397                        None  2022-04-19 12:35:51.127022
# 398  2015-12-12 22:35:15.569310  2015-12-19 19:28:08.809478
# 399  2021-07-29 16:38:06.052542  2021-08-02 22:27:28.713637
# 400  2024-02-14 00:30:15.052542  2024-02-15 00:30:15.052542
#
# [401 rows x 7 columns]

# %%
from sqlalchemy import create_engine

# %%
def db_source_postgres_engine():
    db_username = 'postgres'
    db_password = 'cobapassword'
    db_host = 'localhost:5433'
    db_name = 'pachotel'

    engine_str = f"postgresql://{db_username}:{db_password}@{db_host}/{db_name}"
    engine = create_engine(engine_str)

    return engine

# %%
source_engine = db_source_postgres_engine()
source_engine
# Out:
# Engine(postgresql://postgres:***@localhost:5433/pachotel)

# %%
query = """
SELECT table_name 
FROM information_schema.tables
WHERE table_schema = 'public'
"""
tables_df = pd.read_sql_query(query, source_engine)
table_names = tables_df['table_name'].tolist()  # Daftar nama tabel

print("Tabel yang ditemukan:", table_names)
# Out:
# Tabel yang ditemukan: ['customer', 'reservation', 'reservation_room', 'room', 'payment']

# %%
def get_table_data(table_name):
    query = f"SELECT * FROM {table_name}"
    df = pd.read_sql(query, source_engine)
    return df

# %%
customer_df = get_table_data('customer')
reservation_df = get_table_data('reservation')
reservation_room_df = get_table_data('reservation_room')
room_df = get_table_data('room')
payment_db_df = get_table_data('payment')

# %%
class ExtractAPIPaymentData(luigi.Task):
    def requires(self):
        pass

    def run(self):
        payment_url = 'https://shandytepe.github.io/payment.json'

        response = requests.get(payment_url)
        payment_json = response.json()
        payment_data = payment_json['payment_data']
        payment_df = pd.DataFrame(payment_data)

        payment_df.to_csv(self.output().path, index = False)

    def output(self):
        return luigi.LocalTarget("data_extract/extract_payment_data.csv")

# %%
class ExtractDBHotelData(luigi.Task):
    def requires(self):
        return []
    
    def run(self):            
        source_engine = db_source_postgres_engine()

        query = """
        SELECT table_name 
        FROM information_schema.tables
        WHERE table_schema = 'public'
        """
        tables_df = pd.read_sql_query(query, source_engine)
        table_names = tables_df['table_name'].tolist()
        
        for table in table_names:
            query = f"SELECT * FROM {table}" 
            df = pd.read_sql(query, source_engine)
            
            df.to_csv(f"data_extract/{table}.csv", index = False)
    
    def output(self):
        return luigi.LocalTarget("data_extract/extract_status.txt")

# %%
luigi.build([ExtractAPIPaymentData(), ExtractDBHotelData()], local_scheduler = True)
# Out:
# DEBUG: Checking if ExtractAPIPaymentData() is complete
# INFO: Informed scheduler that task   ExtractAPIPaymentData__99914b932b   has status   DONE
# DEBUG: Checking if ExtractDBHotelData() is complete
# INFO: Informed scheduler that task   ExtractDBHotelData__99914b932b   has status   PENDING
# INFO: Done scheduling tasks
# INFO: Running Worker with 1 processes
# DEBUG: Asking scheduler for work...
# DEBUG: Pending tasks: 1
# INFO: [pid 22052] Worker Worker(salt=3619855634, workers=1, host=zueible, username=LENOVO, pid=22052) running   ExtractDBHotelData()
# INFO: [pid 22052] Worker Worker(salt=3619855634, workers=1, host=zueible, username=LENOVO, pid=22052) done      ExtractDBHotelData()
# DEBUG: 1 running tasks, waiting for next task to finish
# INFO: Informed scheduler that task   ExtractDBHotelData__99914b932b   has status   DONE
# DEBUG: Asking scheduler for work...
# DEBUG: Done
# DEBUG: There are no more tasks to run at this time
# INFO: Worker Worker(salt=3619855634, workers=1, host=zueible, username=LENOVO, pid=22052) was stopped. Shutting down Keep-Alive thread
# INFO:
# ===== Luigi Execution Summary =====
#
# Scheduled 2 tasks of which:
# * 1 complete ones were encountered:
#     - 1 ExtractAPIPaymentData()
# * 1 ran successfully:
#     - 1 ExtractDBHotelData()
#
# This progress looks :) because there were no failed tasks or missing dependencies
#
# ===== Luigi Execution Summary =====
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Validation
# ---

# %%
payment_df.head()
# Out:
#    payment_id  reservation_id provider  account_number payment_status  \
# 0           1               1      Ovo        38137149        Success
# 1           2               2      BCA        42103729        Success
# 2           3               3  Permata        58689635        Success
# 3           4               4      BNI       107161965        Success
# 4           5               5      BSI        14334131         Failed
#
#                  payment_date                 expire_date
# 0  2020-10-20 17:07:04.406780  2020-10-28 18:10:37.175108
# 1  2015-02-28 16:44:56.703511  2015-03-08 05:27:33.443131
# 2  2022-04-03 13:27:30.811447  2022-04-06 14:20:57.846492
# 3  2019-10-04 08:39:56.034805  2019-10-08 02:01:21.209415
# 4                        None  2020-06-14 12:02:55.669148

# %%
n_coloumn = payment_df.shape[1]
n_row = payment_df.shape[0]
print(f"Pada table payment memiliki jumlah {n_row} baris dan {n_coloumn} kolom")
# Out:
# Pada table payment memiliki jumlah 401 baris dan 7 kolom

# %%
for column in payment_df:
    print(f"Column {column} has data type {str(payment_df['payment_id'].dtype)}")
# Out:
# Column payment_id has data type int64
# Column reservation_id has data type int64
# Column provider has data type int64
# Column account_number has data type int64
# Column payment_status has data type int64
# Column payment_date has data type int64
# Column expire_date has data type int64

# %%
for column in payment_df:
    sum_null = payment_df[column].isnull().sum()
    sum_payment = len(payment_df)

    percentage = (sum_null / sum_payment) * 100
    print(f"Columns {column} has percentages missing values {percentage:.0f}%")
# Out:
# Columns payment_id has percentages missing values 0%
# Columns reservation_id has percentages missing values 0%
# Columns provider has percentages missing values 0%
# Columns account_number has percentages missing values 0%
# Columns payment_status has percentages missing values 0%
# Columns payment_date has percentages missing values 21%
# Columns expire_date has percentages missing values 0%
